# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# m = Basemap(projection = 'mill', llcrnrlat = -90, urcrnrlat = 90, llcrnrlon = -180, urcrnrlaon = 180, resolution ='c' )
# m = Basemap(projection='mill', 
#              llcrnrlon=30.3398 ,llcrnrlat=30.3398,urcrnrlon=76.3869,urcrnrlat=76.3869, resolution = 'h', epsg=5520)
m = Basemap(projection='ortho',lat_0 = 0, lon_0 = 0)
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')

m.drawmapboundary(fill_color='aqua')
map()
m.plot(x, y, marker='d',color='m')

plt.title('dfs')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-7a9975e22fb1> in <module>
#       9 x =0
#      10 y = 0
# ---> 11 map(x,y)
#      12 m.plot(x, y, marker='d',color='m')
#      13
#
# TypeError: 'int' object is not iterable
